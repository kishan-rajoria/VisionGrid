# %%
import torch
import torch.nn as nn
from torchvision import models, transforms
from torch.utils.data import DataLoader, Dataset, random_split
from PIL import Image
import os
import json
import shutil

# %%
with open('module_metadata.json') as f:
    data = json.load(f)
labels = []
for key, value in data.items():
    labels.append({
        'image_filepath': value['image_filepath'],
        'anomaly_class': value['anomaly_class']
    })
unique_labels = set(label['anomaly_class'] for label in labels)
label_mapping = {label: idx for idx, label in enumerate(unique_labels)}

# %% [markdown]
# # Data Class

# %%
class IRDataset(Dataset):
    def __init__(self, labels, transform=None):
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        img_path = self.labels[idx]['image_filepath']
        image = Image.open(img_path).convert("RGB")
        label = label_mapping[self.labels[idx]['anomaly_class']]  
        if self.transform:
            image = self.transform(image)
        return image, label

# %% [markdown]
# # Define transformations

# %%
transform = transforms.Compose([
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %% [markdown]
# # create datasets

# %%
dataset = IRDataset(labels=labels, transform=transform)
total_size = len(dataset)
train_size = int(0.6 * total_size)
val_size = int(0.2 * total_size)
test_size = total_size - train_size - val_size
train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

# %%
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# %% [markdown]
# # Load model

# %%
model = models.densenet121(pretrained=True)
# Out:
# c:\Users\win11\anaconda3\envs\cv\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# c:\Users\win11\anaconda3\envs\cv\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
for param in model.parameters():
    param.requires_grad = True

# %%
num_ftrs = model.classifier.in_features
model.classifier = nn.Sequential(
    nn.Linear(num_ftrs, 256),
    nn.ReLU(),
    nn.Dropout(0.5),
    nn.Linear(256, len(label_mapping))
)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.0001)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=7, gamma=0.1)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# %%
for epoch in range(200):
    model.train()
    running_loss = 0.0
    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()

        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    avg_val_loss = val_loss / len(val_loader)
    val_accuracy = correct / total
    print(f"Epoch {epoch+1}, Validation Loss: {avg_val_loss:.4f}, Accuracy: {val_accuracy:.4f}")

    scheduler.step()
# Out:
# Epoch 1, Loss: 1.6264
# Epoch 1, Validation Loss: 1.4961, Accuracy: 0.5637
# Epoch 2, Loss: 1.3984
# Epoch 2, Validation Loss: 1.4070, Accuracy: 0.5780
# Epoch 3, Loss: 1.3368
# Epoch 3, Validation Loss: 1.3433, Accuracy: 0.5978
# Epoch 4, Loss: 1.2940
# Epoch 4, Validation Loss: 1.3240, Accuracy: 0.5975
# Epoch 5, Loss: 1.2695
# Epoch 5, Validation Loss: 1.2786, Accuracy: 0.6198
# Epoch 6, Loss: 1.2207
# Epoch 6, Validation Loss: 1.2386, Accuracy: 0.6185
# Epoch 7, Loss: 1.2042
# Epoch 7, Validation Loss: 1.2545, Accuracy: 0.6152
# Epoch 8, Loss: 1.1557
# Epoch 8, Validation Loss: 1.1841, Accuracy: 0.6350
# Epoch 9, Loss: 1.1431
# Epoch 9, Validation Loss: 1.1771, Accuracy: 0.6382
# Epoch 10, Loss: 1.1362
# Epoch 10, Validation Loss: 1.1431, Accuracy: 0.6400
# Epoch 11, Loss: 1.1177
# Epoch 11, Validation Loss: 1.1545, Accuracy: 0.6470
# Epoch 12, Loss: 1.1057
# Epoch 12, Validation Loss: 1.1608, Accuracy: 0.6395
# Epoch 13, Loss: 1.1005
# Epoch 13, Validation Loss: 1.1478, Accuracy: 0.6418
# Epoch 14, Loss: 1.0986
# Epoch 14, Validation Loss: 1.1549, Accuracy: 0.6452
# Epoch 15, Loss: 1.0890
# Epoch 15, Validation Loss: 1.1498, Accuracy: 0.6448
# Epoch 16, Loss: 1.0911
# Epoch 16, Validation Loss: 1.1128, Accuracy: 0.6538
# Epoch 17, Loss: 1.0790
# Epoch 17, Validation Loss: 1.1342, Accuracy: 0.6480
# Epoch 18, Loss: 1.0898
# Epoch 18, Validation Loss: 1.1471, Accuracy: 0.6465
# Epoch 19, Loss: 1.0752
# Epoch 19, Validation Loss: 1.1458, Accuracy: 0.6495
# Epoch 20, Loss: 1.0776
# Epoch 20, Validation Loss: 1.1251, Accuracy: 0.6538
# Epoch 21, Loss: 1.0794
# Epoch 21, Validation Loss: 1.1243, Accuracy: 0.6498
# Epoch 22, Loss: 1.0797
# Epoch 22, Validation Loss: 1.1111, Accuracy: 0.6580
# Epoch 23, Loss: 1.0783
# Epoch 23, Validation Loss: 1.1323, Accuracy: 0.6468
# Epoch 24, Loss: 1.0814
# Epoch 24, Validation Loss: 1.1341, Accuracy: 0.6495
# Epoch 25, Loss: 1.0768
# Epoch 25, Validation Loss: 1.1194, Accuracy: 0.6580
# Epoch 26, Loss: 1.0875
# Epoch 26, Validation Loss: 1.1506, Accuracy: 0.6470
# Epoch 27, Loss: 1.0867
# Epoch 27, Validation Loss: 1.1377, Accuracy: 0.6512
# Epoch 28, Loss: 1.0908
# Epoch 28, Validation Loss: 1.1313, Accuracy: 0.6482
# Epoch 29, Loss: 1.0741
# Epoch 29, Validation Loss: 1.1141, Accuracy: 0.6587
# Epoch 30, Loss: 1.0886
# Epoch 30, Validation Loss: 1.1434, Accuracy: 0.6460
# Epoch 31, Loss: 1.0781
# Epoch 31, Validation Loss: 1.1488, Accuracy: 0.6455
# Epoch 32, Loss: 1.0887
# Epoch 32, Validation Loss: 1.1189, Accuracy: 0.6510
# Epoch 33, Loss: 1.0898
# Epoch 33, Validation Loss: 1.1236, Accuracy: 0.6498
# Epoch 34, Loss: 1.0702
# Epoch 34, Validation Loss: 1.1452, Accuracy: 0.6500
# Epoch 35, Loss: 1.0758
# Epoch 35, Validation Loss: 1.1289, Accuracy: 0.6490
# Epoch 36, Loss: 1.0863
# Epoch 36, Validation Loss: 1.1498, Accuracy: 0.6465
# Epoch 37, Loss: 1.0838
# Epoch 37, Validation Loss: 1.1420, Accuracy: 0.6452
# Epoch 38, Loss: 1.0764
# Epoch 38, Validation Loss: 1.1252, Accuracy: 0.6472
# Epoch 39, Loss: 1.0879
# Epoch 39, Validation Loss: 1.1264, Accuracy: 0.6488
# Epoch 40, Loss: 1.0748
# Epoch 40, Validation Loss: 1.1411, Accuracy: 0.6490
# Epoch 41, Loss: 1.0825
# Epoch 41, Validation Loss: 1.1420, Accuracy: 0.6442
# Epoch 42, Loss: 1.0783
# Epoch 42, Validation Loss: 1.1319, Accuracy: 0.6478
# Epoch 43, Loss: 1.0851
# Epoch 43, Validation Loss: 1.1236, Accuracy: 0.6532
# Epoch 44, Loss: 1.0757
# Epoch 44, Validation Loss: 1.1422, Accuracy: 0.6498
# Epoch 45, Loss: 1.0827
# Epoch 45, Validation Loss: 1.1439, Accuracy: 0.6420
# Epoch 46, Loss: 1.0811
# Epoch 46, Validation Loss: 1.1276, Accuracy: 0.6525
# Epoch 47, Loss: 1.0745
# Epoch 47, Validation Loss: 1.1273, Accuracy: 0.6475
# Epoch 48, Loss: 1.0808
# Epoch 48, Validation Loss: 1.1307, Accuracy: 0.6530
# Epoch 49, Loss: 1.0799
# Epoch 111, Validation Loss: 1.1319, Accuracy: 0.6490
# Epoch 112, Loss: 1.0873
# Epoch 112, Validation Loss: 1.1259, Accuracy: 0.6530
# Epoch 113, Loss: 1.0820
# Epoch 113, Validation Loss: 1.1394, Accuracy: 0.6450
# Epoch 114, Loss: 1.0804
# Epoch 114, Validation Loss: 1.1356, Accuracy: 0.6505
# Epoch 115, Loss: 1.0781
# Epoch 115, Validation Loss: 1.1278, Accuracy: 0.6538
# Epoch 116, Loss: 1.0886
# Epoch 116, Validation Loss: 1.1142, Accuracy: 0.6562
# Epoch 117, Loss: 1.0757
# Epoch 117, Validation Loss: 1.1306, Accuracy: 0.6510
# Epoch 118, Loss: 1.0762
# Epoch 118, Validation Loss: 1.1296, Accuracy: 0.6540
# Epoch 119, Loss: 1.0833
# Epoch 119, Validation Loss: 1.1248, Accuracy: 0.6540
# Epoch 120, Loss: 1.0832
# Epoch 120, Validation Loss: 1.1279, Accuracy: 0.6565
# Epoch 121, Loss: 1.0865
# Epoch 121, Validation Loss: 1.1414, Accuracy: 0.6428
# Epoch 122, Loss: 1.0956
# Epoch 122, Validation Loss: 1.1440, Accuracy: 0.6472
# Epoch 123, Loss: 1.0799
# Epoch 123, Validation Loss: 1.1390, Accuracy: 0.6455
# Epoch 124, Loss: 1.0839
# Epoch 124, Validation Loss: 1.1329, Accuracy: 0.6512
# Epoch 125, Loss: 1.0806
# Epoch 125, Validation Loss: 1.1398, Accuracy: 0.6485
# Epoch 126, Loss: 1.0916
# Epoch 126, Validation Loss: 1.1173, Accuracy: 0.6542
# Epoch 127, Loss: 1.0731
# Epoch 127, Validation Loss: 1.1296, Accuracy: 0.6445
# Epoch 128, Loss: 1.0771
# Epoch 128, Validation Loss: 1.1587, Accuracy: 0.6432
# Epoch 129, Loss: 1.0854
# Epoch 129, Validation Loss: 1.1388, Accuracy: 0.6545
# Epoch 130, Loss: 1.0819
# Epoch 130, Validation Loss: 1.1422, Accuracy: 0.6485
# Epoch 131, Loss: 1.0833
# Epoch 131, Validation Loss: 1.1280, Accuracy: 0.6542
# Epoch 132, Loss: 1.0848
# Epoch 132, Validation Loss: 1.1290, Accuracy: 0.6508
# Epoch 133, Loss: 1.0900
# Epoch 133, Validation Loss: 1.1432, Accuracy: 0.6448
# Epoch 134, Loss: 1.0838
# Epoch 134, Validation Loss: 1.1453, Accuracy: 0.6442
# Epoch 135, Loss: 1.0981
# Epoch 135, Validation Loss: 1.1063, Accuracy: 0.6555
# Epoch 136, Loss: 1.0771
# Epoch 136, Validation Loss: 1.1404, Accuracy: 0.6472
# Epoch 137, Loss: 1.0894
# Epoch 137, Validation Loss: 1.1267, Accuracy: 0.6538
# Epoch 138, Loss: 1.0800
# Epoch 138, Validation Loss: 1.1297, Accuracy: 0.6495
# Epoch 139, Loss: 1.0779
# Epoch 139, Validation Loss: 1.1278, Accuracy: 0.6488
# Epoch 140, Loss: 1.0747
# Epoch 140, Validation Loss: 1.1369, Accuracy: 0.6465
# Epoch 141, Loss: 1.0878
# Epoch 141, Validation Loss: 1.1221, Accuracy: 0.6518
# Epoch 142, Loss: 1.0897
# Epoch 142, Validation Loss: 1.1342, Accuracy: 0.6525
# Epoch 143, Loss: 1.0843
# Epoch 143, Validation Loss: 1.1365, Accuracy: 0.6440
# Epoch 144, Loss: 1.0822
# Epoch 144, Validation Loss: 1.1417, Accuracy: 0.6548
# Epoch 145, Loss: 1.0914
# Epoch 145, Validation Loss: 1.1282, Accuracy: 0.6538
# Epoch 146, Loss: 1.0740
# Epoch 146, Validation Loss: 1.1251, Accuracy: 0.6545
# Epoch 147, Loss: 1.0865
# Epoch 147, Validation Loss: 1.1486, Accuracy: 0.6455
# Epoch 148, Loss: 1.0838
# Epoch 148, Validation Loss: 1.1389, Accuracy: 0.6512
# Epoch 149, Loss: 1.0904
# Epoch 149, Validation Loss: 1.1532, Accuracy: 0.6460
# Epoch 150, Loss: 1.0737
# Epoch 150, Validation Loss: 1.1509, Accuracy: 0.6402
# Epoch 151, Loss: 1.0778
# Epoch 151, Validation Loss: 1.1369, Accuracy: 0.6388
# Epoch 152, Loss: 1.0798
# Epoch 152, Validation Loss: 1.1298, Accuracy: 0.6482
# Epoch 153, Loss: 1.0851
# Epoch 153, Validation Loss: 1.1408, Accuracy: 0.6438
# Epoch 154, Loss: 1.0697
# Epoch 154, Validation Loss: 1.1177, Accuracy: 0.6490
# Epoch 155, Loss: 1.0729
# Epoch 155, Validation Loss: 1.1240, Accuracy: 0.6532
# Epoch 156, Loss: 1.0806
# Epoch 156, Validation Loss: 1.1306, Accuracy: 0.6492
# Epoch 157, Loss: 1.0870
# Epoch 157, Validation Loss: 1.1230, Accuracy: 0.6532
# Epoch 158, Loss: 1.0877
# Epoch 158, Validation Loss: 1.1325, Accuracy: 0.6525
# Epoch 159, Loss: 1.0875
# Epoch 159, Validation Loss: 1.1429, Accuracy: 0.6458
# Epoch 160, Loss: 1.0851
# Epoch 160, Validation Loss: 1.1343, Accuracy: 0.6455
# Epoch 161, Loss: 1.0767
# Epoch 161, Validation Loss: 1.1370, Accuracy: 0.6445
# Epoch 162, Loss: 1.0785
# Epoch 162, Validation Loss: 1.1269, Accuracy: 0.6508
# Epoch 163, Loss: 1.0794
# Epoch 163, Validation Loss: 1.1217, Accuracy: 0.6510
# Epoch 164, Loss: 1.0834
# Epoch 164, Validation Loss: 1.1150, Accuracy: 0.6530
# Epoch 165, Loss: 1.0802
# Epoch 165, Validation Loss: 1.1502, Accuracy: 0.6448
# Epoch 166, Loss: 1.0775
# Epoch 166, Validation Loss: 1.1317, Accuracy: 0.6508
# Epoch 167, Loss: 1.0881
# Epoch 167, Validation Loss: 1.1531, Accuracy: 0.6500
# Epoch 168, Loss: 1.0813
# Epoch 168, Validation Loss: 1.1142, Accuracy: 0.6510
# Epoch 169, Loss: 1.0803
# Epoch 169, Validation Loss: 1.1293, Accuracy: 0.6458
# Epoch 170, Loss: 1.0912
# Epoch 170, Validation Loss: 1.1310, Accuracy: 0.6520
# Epoch 171, Loss: 1.0745
# Epoch 171, Validation Loss: 1.1203, Accuracy: 0.6512
# Epoch 172, Loss: 1.0888
# Epoch 172, Validation Loss: 1.1382, Accuracy: 0.6472
# Epoch 173, Loss: 1.0865
# Epoch 173, Validation Loss: 1.1088, Accuracy: 0.6565
# Epoch 174, Loss: 1.0857
# Epoch 174, Validation Loss: 1.1290, Accuracy: 0.6488
# Epoch 175, Loss: 1.0953
# Epoch 175, Validation Loss: 1.1334, Accuracy: 0.6505
# Epoch 176, Loss: 1.0781
# Epoch 176, Validation Loss: 1.1203, Accuracy: 0.6468
# Epoch 177, Loss: 1.0947
# Epoch 177, Validation Loss: 1.1417, Accuracy: 0.6498
# Epoch 178, Loss: 1.0793
# Epoch 178, Validation Loss: 1.1346, Accuracy: 0.6510
# Epoch 179, Loss: 1.0847
# Epoch 179, Validation Loss: 1.1148, Accuracy: 0.6518
# Epoch 180, Loss: 1.0887
# Epoch 180, Validation Loss: 1.1195, Accuracy: 0.6528
# Epoch 181, Loss: 1.0878
# Epoch 181, Validation Loss: 1.1352, Accuracy: 0.6485
# Epoch 182, Loss: 1.0803
# Epoch 182, Validation Loss: 1.1335, Accuracy: 0.6438
# Epoch 183, Loss: 1.0804
# Epoch 183, Validation Loss: 1.1307, Accuracy: 0.6522
# Epoch 184, Loss: 1.0851
# Epoch 184, Validation Loss: 1.1296, Accuracy: 0.6495
# Epoch 185, Loss: 1.0728
# Epoch 185, Validation Loss: 1.1466, Accuracy: 0.6482
# Epoch 186, Loss: 1.0820
# Epoch 186, Validation Loss: 1.1529, Accuracy: 0.6398
# Epoch 187, Loss: 1.0693
# Epoch 187, Validation Loss: 1.1207, Accuracy: 0.6498
# Epoch 188, Loss: 1.0965
# Epoch 188, Validation Loss: 1.1419, Accuracy: 0.6518
# Epoch 189, Loss: 1.0738
# Epoch 189, Validation Loss: 1.1427, Accuracy: 0.6418
# Epoch 190, Loss: 1.0742
# Epoch 190, Validation Loss: 1.1384, Accuracy: 0.6488
# Epoch 191, Loss: 1.0808
# Epoch 191, Validation Loss: 1.1491, Accuracy: 0.6450
# Epoch 192, Loss: 1.0822
# Epoch 192, Validation Loss: 1.1436, Accuracy: 0.6492
# Epoch 193, Loss: 1.0795
# Epoch 193, Validation Loss: 1.1189, Accuracy: 0.6518
# Epoch 194, Loss: 1.0799
# Epoch 194, Validation Loss: 1.1136, Accuracy: 0.6545
# Epoch 195, Loss: 1.0781
# Epoch 195, Validation Loss: 1.1355, Accuracy: 0.6515
# Epoch 196, Loss: 1.0849
# Epoch 196, Validation Loss: 1.1193, Accuracy: 0.6520
# Epoch 197, Loss: 1.0801
# Epoch 197, Validation Loss: 1.1375, Accuracy: 0.6502
# Epoch 198, Loss: 1.0865
# Epoch 198, Validation Loss: 1.1361, Accuracy: 0.6430
# Epoch 199, Loss: 1.0697
# Epoch 199, Validation Loss: 1.1317, Accuracy: 0.6452
# Epoch 200, Loss: 1.0807
# Epoch 200, Validation Loss: 1.1255, Accuracy: 0.6480

# %%
# torch.save(model.state_dict(), 'fine_tuned_resnet501.pth')

# %%
torch.save(model.state_dict(), 'fine_tuned_densenet121.pth')

# %%
# Test the model
model.eval()
test_loss = 0.0
correct = 0
total = 0
with torch.no_grad():
    for images, labels in test_loader:
        images, labels = images.to(device), labels.to(device)
        outputs = model(images)
        loss = criterion(outputs, labels)
        test_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

avg_test_loss = test_loss / len(test_loader)
test_accuracy = correct / total
print(f"Test Loss: {avg_test_loss:.4f}, Test Accuracy: {test_accuracy:.4f}")

torch.save(model.state_dict(), 'fine_tuned_densenet121.pth')
# Out:
# Test Loss: 1.0618, Test Accuracy: 0.6710
